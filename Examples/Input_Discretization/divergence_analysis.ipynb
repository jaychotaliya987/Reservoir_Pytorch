# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('../..')))

import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from reservoirgrid.helpers import chaos_utils
from reservoirgrid.helpers import utils
from reservoirgrid.helpers import viz

# %%
path = "../../Examples/Weight_Landscape/results/Chaotic/"
save_path = "../../Examples/Weight_Landscape/Plots/SingleMetric/"
system_name = "Lorenz"
system_path = os.path.join(path, system_name)

# %%
file = os.path.join(system_path, "75.0.pkl")
with open(file, "rb") as f:
    data_10 = pickle.load(f)

# %%
data_10
# Out:
# [{'parameters': {'SpectralRadius': np.float64(0.71),
#    'LeakyRate': np.float64(0.71),
#    'InputScaling': np.float64(0.59)},
#   'metrics': {'RMSE': 0.44467339626132224},
#   'predictions': tensor([[-0.3603, -0.4177,  0.2677],
#           [-0.3715, -0.4327,  0.2460],
#           [-0.3837, -0.4503,  0.2270],
#           ...,
#           [ 0.0639, -0.0599, -0.4668],
#           [ 0.0392, -0.0822, -0.4648],
#           [ 0.0147, -0.1072, -0.4719]], dtype=torch.float64),
#   'readout_weights': array([[-0.00988369,  0.00038254,  0.00176131, ...,  0.001655  ,
#           -0.00046181, -0.00208054],
#          [-0.0191203 , -0.0057595 ,  0.00096271, ...,  0.00163705,
#            0.00333668, -0.00626657],
#          [-0.01872027,  0.00899364, -0.01256561, ..., -0.02416198,
#           -0.00498744,  0.00265484]], shape=(3, 1300)),
#   'true_value': array([[-0.36095741, -0.41188175,  0.26993806],
#          [-0.37120656, -0.42313015,  0.24946626],
# ...

# %%
all_lyapunov = []
all_kldiv = []
all_params = []
all_jsdiv = []
all_skl = []
all_RMSE = []

for data in data_10:
    lyap1 = chaos_utils.lyapunov_time(data["true_value"], data["predictions"])
    Kldiv = chaos_utils.kl_divergence(data["true_value"], data["predictions"])
    jsdiv = chaos_utils.js_divergence(data["true_value"], data["predictions"])
    skl = chaos_utils.symmetric_kl(data["true_value"], data["predictions"])
    RMSE = data["metrics"]["RMSE"]


    all_skl.append(skl)
    all_jsdiv.append(jsdiv)
    all_lyapunov.append(lyap1)
    all_kldiv.append(Kldiv)
    all_RMSE.append(RMSE)
    
    params = data["parameters"]
    all_params.append(params)

# %%
jsidx = np.argpartition(all_jsdiv, 10)[:10]
klidx = np.argpartition(all_kldiv, 10)[:10]
sklidx = np.argpartition(all_skl, 10)[:10]
rmseidx = np.argpartition(all_RMSE, 10)[:10]

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

def plot_attractor_grid(indices, metric_values, data_source, viz_module, filename="output.png", cols=5):
    """
    Generates a grid of 3D attractor plots based on provided indices.

    Args:
        indices (array-like): Array of indices to plot (e.g., jsidx, klidx).
        metric_values (array-like): The array containing the score values (e.g., all_jsdiv, all_skl) used for titles.
        data_source (dict): The dictionary containing the dataset (e.g., data_10).
        viz_module (obj): The visualization object containing the 'compare_plot' function.
        filename (str): Name of the file to save the image to.
        cols (int): Number of columns in the grid.
    """
    
    n = len(indices)
    rows = int(np.ceil(n / cols))

    # Define the visual style for the 3D scenes
    clean_scene = dict(
        camera=dict(
            eye=dict(x=-1.5, y=1.5, z=0.5),
            center=dict(x=0, y=0, z=0),
            up=dict(x=0, y=0, z=1)
        ),
        xaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        yaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        zaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        aspectmode="data"    
    )

    # Create subplot figure
    fig = make_subplots(
        rows=rows, cols=cols,
        specs=[[{"type": "scene"} for _ in range(cols)] for _ in range(rows)],
        # Use the specific metric value for the title of each subplot
        subplot_titles=[f"{metric_values[u]:.4f}" for u in indices],
        horizontal_spacing=0,
        vertical_spacing=0.02 # A tiny vertical spacing usually helps titles not overlap
    )

    # Loop and add traces
    for i, u in enumerate(indices):
        r, c = divmod(i, cols)
        
        # Extract data
        # Note: Assuming 'predictions' is a Tensor based on your .numpy() call
        best_js = np.array([
            data_source[u]["true_value"],
            data_source[u]["predictions"].numpy()
        ])
        
        # Generate the comparison plot using your viz module
        subfig = viz_module.compare_plot(best_js) 

        # Extract traces and add them into the specific subplot location
        for trace in subfig.data:
            fig.add_trace(trace, row=r+1, col=c+1)

    # Apply clean layout to all scenes
    layout_updates = {}
    for i in range(1, rows*cols + 1):
        scene_name = "scene" if i == 1 else f"scene{i}"
        layout_updates[scene_name] = clean_scene

    fig.update_layout(
        margin=dict(l=0, r=0, t=30, b=0),
        showlegend=False,
        **layout_updates
    )

    # Save and Show
    print(f"Saving figure to {filename}...")
    fig.write_image(filename, width=1250, height=rows*250) # Adjusted height dynamically based on rows

# %%
plot_attractor_grid(jsidx, all_jsdiv, data_10, viz, filename=os.path.join(save_path, "Lorenz_JSDivergence_Best10.png"))
plot_attractor_grid(klidx, all_kldiv, data_10, viz, filename=os.path.join(save_path, "Lorenz_KLDivergence_Best10.png"))
plot_attractor_grid(sklidx, all_skl, data_10, viz, filename=os.path.join(save_path, "Lorenz_SymmetricKL_Best10.png"))
plot_attractor_grid(rmseidx, all_RMSE, data_10, viz, filename=os.path.join(save_path, "Lorenz_RMSE_Best10.png"))
# Out:
# Saving figure to ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_JSDivergence_Best10.png...
# Saving figure to ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_KLDivergence_Best10.png...
# Saving figure to ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_SymmetricKL_Best10.png...
# Saving figure to ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_RMSE_Best10.png...

# %%
viz.compare_plot([data_10[int(rmseidx[0])]["true_value"][:,1], data_10[int(rmseidx[0])]["predictions"][:,1].numpy()], title="Best RMSE Prediction vs True Value", legend_names=["True Value", "Prediction"])

# %%
df_param = pd.DataFrame(all_params)
df_param['JSDiv'] = all_jsdiv
df_param['KLDiv'] = all_kldiv
df_param['SymKL'] = all_skl
df_param['RMSE'] = all_RMSE

viz.plot_correlation_matrix(df_param,save_path=save_path+"Lorenz_CorrelationMatrix.png")
# Out:
# Correlation Matrix saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_CorrelationMatrix.png

# %%
viz.plot_parameter_distributions(df_param, metric= "JSDiv", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_JSDiv_ParameterDistributions.png")
viz.plot_parameter_distributions(df_param, metric= "KLDiv", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_KLDiv_ParameterDistributions.png")
viz.plot_parameter_distributions(df_param, metric= "SymKL", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_SymmetricKL_ParameterDistributions.png")
# Out:
# Distribution plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_JSDiv_ParameterDistributions.png
# Distribution plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_KLDiv_ParameterDistributions.png
# Distribution plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_SymmetricKL_ParameterDistributions.png

# %%
viz.plot_parallel_coordinates(df_param, metric= "SymKL", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_SymmetricKL_ParallelCoordinates.png")
viz.plot_parallel_coordinates(df_param, metric= "JSDiv", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_JSDiv_ParallelCoordinates.png")
viz.plot_parallel_coordinates(df_param, metric= "KLDiv", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_KLDiv_ParallelCoordinates.png")
viz.plot_parallel_coordinates(df_param, metric= "RMSE", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_RMSE_ParallelCoordinates.png")
# Out:
# Parallel Coordinates plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_SymmetricKL_ParallelCoordinates.png
# Parallel Coordinates plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_JSDiv_ParallelCoordinates.png
# Parallel Coordinates plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_KLDiv_ParallelCoordinates.png
# Parallel Coordinates plot saved to: ../../Examples/Weight_Landscape/Plots/SingleMetric/Lorenz_RMSE_ParallelCoordinates.png
