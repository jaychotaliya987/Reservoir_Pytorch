# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('../..')))

import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from reservoirgrid.helpers import chaos_utils
from reservoirgrid.helpers import utils
from reservoirgrid.helpers import viz

# %%
path = "results/Chaotic/"
save_path = "Plots/SingleMetric/LHS"
system_name = "LorenzLHS"
system_path = os.path.join(path, system_name)

# %%
file = os.path.join(system_path, "75.0.pkl")
with open(file, "rb") as f:
    data_10 = pickle.load(f)

# %%
rows = []
for data in data_10:
    # Extract values
    true, pred = data["true_value"], data["predictions"]
    
    # Build a dictionary for this iteration
    row = {
        "lyapunov": chaos_utils.lyapunov_time(true, pred),
        "kl_div": chaos_utils.kl_divergence(true, pred),
        "js_div": chaos_utils.js_divergence(true, pred),
        "skl": chaos_utils.symmetric_kl(true, pred),
        "RMSE": data["metrics"]["RMSE"],
        "params": data["parameters"]
    }
    rows.append(row)

# Create the DataFrame
df = pd.DataFrame(rows)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np

def plot_attractor_grid(indices, metric_values, data_source, viz_module, filename="output.png", cols=5):
    """
    Args:
        indices (array-like): The integer indices from the DataFrame (df.index.values).
        metric_values (array-like): The actual score values (df.values).
        data_source (list/dict): The original data_10 list.
        viz_module: Your visualization module.
    """
    
    n = len(indices)
    rows = int(np.ceil(n / cols))

    clean_scene = dict(
        camera=dict(eye=dict(x=-1.5, y=1.5, z=0.5)),
        xaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        yaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        zaxis=dict(showbackground=False, showgrid=False, zeroline=False, showticklabels=False, title=''),
        aspectmode="data"    
    )

    # The fix: Zip indices and metric_values together for subplot titles
    fig = make_subplots(
        rows=rows, cols=cols,
        specs=[[{"type": "scene"} for _ in range(cols)] for _ in range(rows)],
        subplot_titles=[f"Score: {val:.4f}" for val in metric_values],
        horizontal_spacing=0.02,
        vertical_spacing=0.05 
    )

    # Use enumerate to keep track of the subplot position (i) 
    # while using 'u' to fetch data from the original data_source
    for i, u in enumerate(indices):
        r, c = divmod(i, cols)
        
        # Pull from data_source using the original index 'u'
        best_data = np.array([
            data_source[u]["true_value"],
            data_source[u]["predictions"].numpy()
        ])
        
        subfig = viz_module.compare_plot(best_data) 

        for trace in subfig.data:
            fig.add_trace(trace, row=r+1, col=c+1)

    # Update layout for all scenes
    layout_updates = {
        (f"scene{i}" if i > 1 else "scene"): clean_scene 
        for i in range(1, n + 1)
    }

    fig.update_layout(
        margin=dict(l=10, r=10, t=50, b=10),
        showlegend=False,
        **layout_updates
    )

    print(f"Saving figure to {filename}...")
    fig.write_image(filename, width=1250, height=max(400, rows*300))

# %%
# List of columns we want to analyze
metrics = {
    "js_div": "JSDivergence",
    "kl_div": "KLDivergence",
    "skl": "SymmetricKL",
    "RMSE": "RMSE"
}

for col, label in metrics.items():
    # 1. Get the 10 rows with the smallest values for this metric
    # .nsmallest returns a Series/DataFrame sorted from smallest to largest
    best_subset = df[col].nsmallest(10)
    
    # 2. Extract the indices and the values
    idx = best_subset.index.values
    values = best_subset.values
    
    # 3. Plot
    path = os.path.join(save_path, f"Lorenz_{label}_Best10.png")
    plot_attractor_grid(idx, values, data_10, viz, filename=path)
# Out:
# Saving figure to Plots/SingleMetric/LHS/Lorenz_JSDivergence_Best10.png...
# Saving figure to Plots/SingleMetric/LHS/Lorenz_KLDivergence_Best10.png...
# Saving figure to Plots/SingleMetric/LHS/Lorenz_SymmetricKL_Best10.png...
# Saving figure to Plots/SingleMetric/LHS/Lorenz_RMSE_Best10.png...

# %%
# Get the index of the best (minimum) RMSE
best_idx = int(df['RMSE'].idxmin())

# Extract values for the second dimension ([:, 1])
# We ensure the prediction is a numpy array for plotting
true_y = data_10[best_idx]["true_value"][:, 1]
pred_y = data_10[best_idx]["predictions"][:, 1].numpy()

# Plot
viz.compare_plot(
    [true_y, pred_y], 
    title=f"Best RMSE Prediction (Index {best_idx}) vs True Value", 
    legend_names=["True Value", "Prediction"]
)

# %%
# 1. Expand the 'params' dictionary column into individual columns
df_params = pd.json_normalize(df['params'])

# 2. Combine it with the original metrics (dropping the original 'params' dict column)
full_df = pd.concat([df.drop(columns=['params']), df_params], axis=1)

# 3. Ensure everything is numeric (Correlation needs numbers, not strings)
numeric_df = full_df.select_dtypes(include=[np.number])

# 4. Run your correlation function
viz.plot_correlation_matrix(
    numeric_df, 
    save_path=os.path.join(save_path, "Lorenz_CorrelationMatrix.png")
)
# Out:
# Correlation Matrix saved to: Plots/SingleMetric/LHS/Lorenz_CorrelationMatrix.png

# %%
viz.plot_parameter_distributions(numeric_df, metric= "js_div", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_JSDiv_ParameterDistributions.png")
viz.plot_parameter_distributions(numeric_df, metric= "kl_div", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_KLDiv_ParameterDistributions.png")
viz.plot_parameter_distributions(numeric_df, metric= "skl", params=["SpectralRadius", "LeakyRate", "InputScaling"], save_path=save_path+"Lorenz_SymmetricKL_ParameterDistributions.png")
# Out:
# Distribution plot saved to: Plots/SingleMetric/LHSLorenz_JSDiv_ParameterDistributions.png
# Distribution plot saved to: Plots/SingleMetric/LHSLorenz_KLDiv_ParameterDistributions.png
# Distribution plot saved to: Plots/SingleMetric/LHSLorenz_SymmetricKL_ParameterDistributions.png

# %%
import numpy as np

# 1. Expand the parameters into columns
df_expanded = pd.concat([df.drop(columns=['params']), pd.json_normalize(df['params'])], axis=1)

# 2. Define your target values
target = {
    'SpectralRadius': 1.1,
    'InputScaling': 1.3,
    'LeakyRate': 0.4
}

# 3. Calculate the absolute distance for each parameter and sum them
# (Optional: Normalize if parameters have very different scales)
diffs = (
    (df_expanded['SpectralRadius'] - target['SpectralRadius'])**2 +
    (df_expanded['InputScaling'] - target['InputScaling'])**2 +
    (df_expanded['LeakyRate'] - target['LeakyRate'])**2
)

# 4. Get the index of the minimum distance
closest_idx = diffs.idxmin()

# 5. Extract the data
best_match_params = df_expanded.loc[closest_idx]
true_traj = data_10[closest_idx]["true_value"]
pred_traj = data_10[closest_idx]["predictions"]

print(f"Closest match found at Index {closest_idx}")
print(f"Target SR: {target['SpectralRadius']} -> Found: {best_match_params['SpectralRadius']}")
print(f"Target IS: {target['InputScaling']} -> Found: {best_match_params['InputScaling']}")
print(f"Target LR: {target['LeakyRate']} -> Found: {best_match_params['LeakyRate']}")
# Out:
# Closest match found at Index 557
# Target SR: 1.1 -> Found: 1.12
# Target IS: 1.3 -> Found: 0.88
# Target LR: 0.4 -> Found: 0.4

# %%
# Compare the Y-dimension (Lorenz Horizontal Gradient)
viz.compare_plot(
    [true_traj, pred_traj.numpy()], 
    title=f"Closest Run (Index {closest_idx}) | RMSE: {best_match_params['RMSE']:.4f}",
    legend_names=["True", "Predicted"]
).show()

# %%
# List of metrics you want to visualize
metrics = ["skl", "js_div", "kl_div", "RMSE"]

# The hyperparameters we are focusing on
hp_params = ["SpectralRadius", "LeakyRate", "InputScaling"]

for metric in metrics:
    # Build the filename dynamically
    filename = f"Lorenz_{metric}_ParallelCoordinates.png"
    save_full_path = os.path.join(save_path, filename)
    
    # Call the plotting function
    viz.plot_parallel_coordinates(
        numeric_df, 
        metric=metric, 
        params=hp_params, 
        save_path=save_full_path
    )
# Out:
# Parallel Coordinates plot saved to: Plots/SingleMetric/LHS/Lorenz_skl_ParallelCoordinates.png
# Parallel Coordinates plot saved to: Plots/SingleMetric/LHS/Lorenz_js_div_ParallelCoordinates.png
# Parallel Coordinates plot saved to: Plots/SingleMetric/LHS/Lorenz_kl_div_ParallelCoordinates.png
# Parallel Coordinates plot saved to: Plots/SingleMetric/LHS/Lorenz_RMSE_ParallelCoordinates.png
